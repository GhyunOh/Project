# %%
from urllib.parse import urlencode, quote_plus
from urllib import parse
import requests as rq
import json 
import pandas as pd 
from pandas.io.json import json_normalize
from json import JSONDecodeError

# %%
url = 'http://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList'

# %%
data = {}
header = ['stnId', 'stnNm', 'tm', 'avgTa', 'minTa', 'minTaHrmt', 'maxTa',
       'maxTaHrmt', 'mi10MaxRn', 'mi10MaxRnHrmt', 'hr1MaxRn', 'hr1MaxRnHrmt',
       'sumRnDur', 'sumRn', 'maxInsWs', 'maxInsWsWd', 'maxInsWsHrmt', 'maxWs',
       'maxWsWd', 'maxWsHrmt', 'avgWs', 'hr24SumRws', 'maxWd', 'avgTd',
       'minRhm', 'minRhmHrmt', 'avgRhm', 'avgPv', 'avgPa', 'maxPs',
       'maxPsHrmt', 'minPs', 'minPsHrmt', 'avgPs', 'ssDur', 'sumSsHr',
       'hr1MaxIcsrHrmt', 'hr1MaxIcsr', 'sumGsr', 'ddMefs', 'ddMefsHrmt',
       'ddMes', 'ddMesHrmt', 'sumDpthFhsc', 'avgTca', 'avgLmac', 'avgTs',
       'minTg', 'avgCm5Te', 'avgCm10Te', 'avgCm20Te', 'avgCm30Te', 'avgM05Te',
       'avgM10Te', 'avgM15Te', 'avgM30Te', 'avgM50Te', 'sumLrgEv', 'sumSmlEv',
       'n99Rn', 'iscs', 'sumFogDur']
region_code = [133]
df = pd.DataFrame(columns=header)

# %%
for region in region_code:
    for year in range(2021,2022):
        start_month = str(year) + "0605"
        end_month = str(year) +"0711"
        for page in range(1,8):
            queryParams = '?' + parse.urlencode({ parse.quote_plus('ServiceKey') : 'VFK/ktW6424VcSedQvSsbOj745JgyeOZ9uyna9yP8uNQX7CMlQzoAlc+6eNdEre+mDUUtoP7l2MMUonKrjXnTg==',
                                           parse.quote_plus('pageNo') : page,
                                           parse.quote_plus('numOfRows') : '10',
                                           parse.quote_plus('dataType') : 'JSON',
                                           parse.quote_plus('dataCd') : 'ASOS',
                                           parse.quote_plus('dateCd') : 'DAY',
                                           parse.quote_plus('startDt') : start_month,
                                           parse.quote_plus('endDt') : end_month,
                                           parse.quote_plus('stnIds') : region })
            request = rq.get(url + queryParams)
            try:
                data = request.json()
                new_df = pd.json_normalize(data['response']['body']['items']['item'])
            except (JSONDecodeError,KeyError):
                pass
            else:
                print(region," ",year)
                df = df.append(new_df, ignore_index = True)
# Out:
# 133   2021
# 133   2021
# 133   2021
# 133   2021

# %%
df
# Out:
#    stnId stnNm          tm avgTa minTa minTaHrmt maxTa maxTaHrmt mi10MaxRn  \
# 0    133    대전  2021-06-05  21.5  16.1        56  26.1      1522
# 1    133    대전  2021-06-06  23.4  18.6       534  28.5      1551
# 2    133    대전  2021-06-07  23.3  16.9       544  29.5      1624
# 3    133    대전  2021-06-08  24.8  18.7       458  31.2      1600
# 4    133    대전  2021-06-09  26.9  20.1       556  32.9      1536
# 5    133    대전  2021-06-10  25.7  21.2      2400  31.6      1452         0
# 6    133    대전  2021-06-11  23.5  19.9       407  28.7      1536         1
# 7    133    대전  2021-06-12  25.3  19.7       456  30.7      1526
# 8    133    대전  2021-06-13  25.2  21.9       653  31.0      1638
# 9    133    대전  2021-06-14  24.9  20.9       209  30.5      1535         0
# 10   133    대전  2021-06-15  22.6  21.1      2033  24.1      1705         0
# 11   133    대전  2021-06-16  23.6  21.3         7  27.2      1533
# 12   133    대전  2021-06-17  22.1  19.6       457  25.4      1348         0
# 13   133    대전  2021-06-18  21.2  19.7      2357  23.5      1653         0
# 29            26  ...     24.9     23.4     20.9     17.0     15.5      1.7
# 30          2156  ...     24.5     23.1     21.2     17.1     15.5      1.8
# 31          1704  ...     24.3     22.9     21.2     17.1     15.5      1.3
# 32            25  ...     24.4     22.8     21.2     17.2     15.5      1.9
# 33           205  ...     25.3     23.2     21.4     17.2     15.5      3.4
# 34            50  ...     25.6     23.2     21.7     17.7     15.6      3.6
# 35          1547  ...     25.9     23.3     21.7     17.7     15.6      3.5
# 36                ...     26.2     23.5     21.7     17.8     15.6      3.0
#
#    sumSmlEv n99Rn                                               iscs sumFogDur
# 0       4.6                    {박무}2050-{박무}{강도0}2100-{박무}{강도1}2400-
# 1       7.2                                -{박무}-{박무}{강도0}0300-0555.
# 2       6.0
# 3       6.4
# 4       7.8
# 5       5.0  14.2    {비}1740-{비}{강도0}1800-{비}{강도0}2100-{비}{강도0}2400-
# 6       4.8                    -{비}-{비}{강도0}0300-0450. {비}0755-0825.
# 7       5.7             {박무}0355-{박무}{강도0}0600-0830. {햇무리}0930-1020.
# 8       5.8        {박무}0145-{박무}{강도0}0300-{박무}{강도0}0600-{박무}{강도0}...
# 9       4.5   0.0  -{박무}-{박무}{강도0}0300-{박무}{강도0}0600-{박무}{강도0}090...
# 10      2.6   1.9  {비}1020-{비}{강도0}1200-1410. {비}1755-{비}{강도0}180...
# 11      4.8
# 12      2.4   1.5  {비}1625-{비}{강도0}1800-1930. {비}2130-2155. {비}22...
# 13      2.2   0.0  {비}0015-{비}{강도0}0300-{비}{강도0}0600-0620. {박무}04...
# 14      6.9
# 15      7.6                                  {박무}2355-{박무}{강도0}2400-
# 16      7.2                  -{박무}-{박무}{강도0}0300-{박무}{강도0}0600-0840.
# 17      4.9
# 18      2.0   6.7  {박무}0240- {박무}{강도0}0300-{박무}{강도0}0600-0815. {소...
# 19      5.0        -{박무}-{박무}{강도0}0300-{박무}{강도0}0600-{박무}{강도0}090...
# 20      6.0  27.2  {박무}0125-{박무}{강도0}0300-{박무}{강도0}0600-0735. {소나...
# 21      4.0   0.0  -{소나기}-{시정(미만)}{1km}{소나기}0201-{시정(미만)}{0.5km}{...
# 22      5.8   0.5  {박무}0230-0305. {박무}0315-{박무}{강도1}0600-0745. {소...
# 23      6.0   0.0                                    {소나기}1620-1720.
# 24      4.0  24.2  {박무}0425-{박무}{강도0}0600-0615. {소나기}1345-{시정(미만)...
# 25      4.9   4.3  -{박무}-{박무}{강도1}0300-{박무}{강도0}0600-{박무}{강도0}090...
# 26      6.5        -{박무}-{박무}{강도1}0300-{박무}{강도2}0600-{박무}{강도0}090...
# 27      6.9
# 28           55.5  {비}1155-{비}{강도0}1200-{비}{강도0}1500-{비}{강도0}1800...
# 29      2.5   0.4  -{박무}-0255. -{비}-{비}{강도0}0300-0405. {안개비}0555-...
# 30      2.6   5.6  {햇무리}1105-1145. {비}1655-{비}{강도0}1800-{비}{강도0}2...
# 31      1.9  17.9  {비}0110-0155. {박무}0115-{박무}{강도0}0300-0510. {박무...
# 32      2.8  38.8  -{박무}-0155. {박무}0215-{박무}{강도0}0300-0315. -{비}-...
# 33      4.9   4.2  {박무}0015-0025. {박무}0045-{박무}{강도1}0300-0415. -{...
# 34      5.1   0.0  {박무}0050-{박무}{강도0}0300-{박무}{강도0}0600-0825. -{비...
# 35      5.0  10.2  {박무}0155-0205. {비}0430-0450. {박무}0520-{박무}{강도0...
# 36      4.3   0.0                                    {소나기}0515-0535.
#
# [37 rows x 62 columns]

# %%
df.to_csv("./data1.txt",sep = ',',encoding='utf-8-sig',index=False)
